# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
from src.utils import utils

PROJECT_DIR = os.getcwd()

# %%
# editable part
dataset_name = "milk_stage2"
run_name = "run3"
dataset_path = f"{PROJECT_DIR}/dataset/{dataset_name}/result/{run_name}"

# %%
class Tools:
    def __init__(self):
        pass

    @staticmethod
    def reproject_ray(intrinsic, extrinsic, uv):
        # extract oriagin and direction
        origin = extrinsic[:3, 3]
        fx, fy, cx, cy = intrinsic[0, 0], intrinsic[1, 1], intrinsic[0, 2], intrinsic[1, 2]
        norm_coor = np.array([(uv[0] - cx) / fx, - (uv[1] - cy) / fy, 1])
        direction = extrinsic[:3, :3].dot(norm_coor / np.linalg.norm(norm_coor))
        return origin, direction

    @staticmethod
    def rotation_matrix_to_rodriguez(R):
        # R = inv_proj_P2[:3, :3]
        angle = np.arccos((np.trace(R) - 1) / 2) + 1.e-10
        axis = 1 / (2 * np.sin(angle)) * np.array([R[2, 1] - R[1, 2], R[0, 2] - R[2, 0], R[1, 0] - R[0, 1]])

        # Calculate Rodriguez rotation vector
        rodriguez_vector = angle * axis
        return rodriguez_vector

    @staticmethod
    def rodriguez_to_rotation_matrix(rodriguez_vector):
        # Calculate angle of rotation and unit axis vector
        angle = np.linalg.norm(rodriguez_vector)
        axis = rodriguez_vector / angle if angle != 0 else np.array([0, 0, 0])

        # Rodrigues' rotation formula
        skew_symmetric = np.array([[0, -axis[2], axis[1]],
                                [axis[2], 0, -axis[0]],
                                [-axis[1], axis[0], 0]])
        rotation_matrix = np.eye(3) + np.sin(angle) * skew_symmetric + (1 - np.cos(angle)) * np.dot(skew_symmetric, skew_symmetric)
        return rotation_matrix

# %% [markdown]
# ### Generate images from specified dataset and run name

# %%
# %matplotlib agg

for i in range(35, len(glob.glob(os.path.join(dataset_path, "record_*.txt")))):
    # camera_intrinsic = np.array([[931.81027925, 0. , 960.], [0. ,931.81027925, 540.], [0. ,0. ,1.]])
    camera_intrinsic = np.array([[931.81027925, 0. , 960.], [0. ,931.81027925, 540.], [0. ,0. ,1.]])
        
    # --- read training data
    training_data = np.array(utils.read_txt(os.path.join(dataset_path, f"record_{i}.txt"))[0][1:-1].split(", ")).astype(float)
    num_camera, num_pts, data = int(training_data[0]), int(training_data[1]), training_data[2:]
    param_camera_temp = data[:6*num_camera].reshape(-1, 6)
    param_pts = data[6*num_camera:].reshape(-1, 3)

    param_camera = [np.eye(4) for i in param_camera_temp]
    param_camera_origin_direction = [np.zeros(12) for i in param_camera_temp]
    for j, cam_rodrig in enumerate(param_camera_temp):
        param_camera[j][:3, 3] = cam_rodrig[:3]
        param_camera[j][:3, :3] = Tools.rodriguez_to_rotation_matrix(cam_rodrig[3:])
        # ray = Tools.reproject_ray(camera_intrinsic, param_camera[j], (960, 540))
        param_camera_origin_direction[j][:3] = cam_rodrig[:3]
        # param_camera_origin_direction[j][3:6] = ray[1]
        # plot x y z
        dir_x, dir_y, dir_z = np.array([1, 0, 0, 1]), np.array([0, 1, 0, 1]), np.array([0, 0, 1, 1])
        param_camera_origin_direction[j][3:6] = param_camera[j].dot(dir_x)[:3]
        param_camera_origin_direction[j][6:9] = param_camera[j].dot(dir_y)[:3]
        param_camera_origin_direction[j][9:12] = param_camera[j].dot(dir_z)[:3]
        
    param_camera = np.array(param_camera)
    param_camera_origin_direction = np.array(param_camera_origin_direction)

    # --- read known data
    known_data = utils.import_json(os.path.join(dataset_path, f"record_{i}.json"))
    known_camera = np.array(known_data["camera"]).reshape(-1, 4, 4)
    known_pts = np.array(known_data["pts"]).reshape(-1, 3)

    fixed_camera_origin_direction = [np.zeros(12) for i in known_camera]
    for j, ext_cam in enumerate(known_camera):
        # ray = Tools.reproject_ray(camera_intrinsic, ext_cam, (960, 540))
        fixed_camera_origin_direction[j][:3] = ext_cam[:3, 3]
        # fixed_camera_origin_direction[j][3:] = ray[1]
        dir_x, dir_y, dir_z = np.array([1, 0, 0, 1]), np.array([0, 1, 0, 1]), np.array([0, 0, 1, 1])
        fixed_camera_origin_direction[j][3:6] = ext_cam.dot(dir_x)[:3]
        fixed_camera_origin_direction[j][6:9] = ext_cam.dot(dir_y)[:3]
        fixed_camera_origin_direction[j][9:12] = ext_cam.dot(dir_z)[:3]

    fixed_camera_origin_direction = np.array(fixed_camera_origin_direction)

    ax = plt.figure(figsize=(15, 10)).add_subplot(projection='3d')

    # is_training_step_1 = len(param_camera_origin_direction) == 2
    is_training_step_1 = True

    # use ratio from the 2nd camera
    # ratio = 1 / np.linalg.norm(fixed_camera_origin_direction[1][:3])
    # param_pts *= ratio
    # param_camera_origin_direction *= ratio
    # known_pts *= ratio
    # fixed_camera_origin_direction *= ratio

    # training - scatter pt and cam
    ax.scatter(xs=param_pts[:, 0], ys=param_pts[:, 1], zs=param_pts[:, 2], s=3, zdir='y', label='Training pts', c='magenta')
    ax.scatter(xs=param_camera_origin_direction[:, :3][:, 0], ys=param_camera_origin_direction[:, :3][:, 1], zs=param_camera_origin_direction[:, :3][:, 2], zdir='y', label='Training camera', c='r')
    ax.scatter(xs=known_pts[:, 0], ys=known_pts[:, 1], zs=known_pts[:, 2], zdir='y', s=3, label='Known pts', c='cyan')

    # training - plot cam

    color = ["r", "g", "b"]
    arrow_ratio = 0.5
    num_camera_training = len(param_camera_origin_direction)
    for cam_data_param in param_camera_origin_direction:
        for k_idx, k in enumerate(cam_data_param[3:].reshape(3, 3)):
            start = cam_data_param[:3]
            end = k / np.linalg.norm(k - start)# / np.linalg.norm(k - start)#cam_data[:3] + cam_data[3:]
            delta = end - start
            end = start + arrow_ratio * delta
            poses = np.array([start, end]).reshape(-1, 3)
            ax.plot(xs=poses[:, 0], ys=poses[:, 1], zs=poses[:, 2], zdir="y", c=color[k_idx])

    if is_training_step_1:
        fixed_camera_origin_direction = fixed_camera_origin_direction[:-num_camera_training + 1]
        ax.scatter(xs=fixed_camera_origin_direction[:, :3][:, 0], ys=fixed_camera_origin_direction[:, :3][:, 1], zs=fixed_camera_origin_direction[:, :3][:, 2], zdir='y', label='Known camera', c='g')
        # known - plot cam
        for cam_data_fixed in fixed_camera_origin_direction:
            for k_idx, k in enumerate(cam_data_fixed[3:].reshape(3, 3)):
                start = cam_data_fixed[:3]
                end = k / np.linalg.norm(k - start)# / np.linalg.norm(k)#cam_data[:3] + cam_data[3:]
                delta = end - start
                end = start + arrow_ratio * delta
                # end = cam_data[:3] + cam_data[3:6]
                poses = np.array([start, end]).reshape(-1, 3)
                ax.plot(xs=poses[:, 0], ys=poses[:, 1], zs=poses[:, 2], zdir="y", c=color[k_idx])
    else:
        ax.scatter(xs=[], ys=[], zs=[], zdir='y', label='Known camera', c='g')


    # print(param_camera_origin_direction, fixed_camera_origin_direction)
    # print()

    # save figure
    img_output_filename = os.path.join(dataset_path, f"record_{i}.jpg")
    ax.view_init(elev=30., azim=-45, roll=0)
    ax.set_xlabel("X")
    ax.set_ylabel("Z")
    ax.set_zlabel("Y")
    # ax.set_xlim(-1.25, 1.25)
    # ax.set_ylim(-0.5, 2)
    # ax.set_zlim(0, 1.5)
    ax.set_xlim(-2.5, 2.5)
    ax.set_ylim(-0.5, 4.5)
    ax.set_zlim(0, 5)
    # ax.set_xlim(-5, 5)
    # ax.set_ylim(-1, 9)
    # ax.set_zlim(0, 10)

    ax.legend()
    ax.figure.savefig(img_output_filename)

    # plt.clf()
    # plt.gcf().clear()
    plt.close()

    # if i == 100:
    #     break

# %% [markdown]
# ### Generate video file from images

# %%
max_frame = 324
imgs = [os.path.join(dataset_path, f"record_{i}.jpg") for i in np.arange(len(glob.glob(os.path.join(dataset_path, "*.jpg"))))[:max_frame]][::1]

fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter(f'output_{dataset_name}.avi', fourcc, 30.0, (1500, 1000))

for im_path in imgs[:]:
    im = cv2.imread(im_path)
    # im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    print(im_path, os.path.exists(im_path))

    out.write(im)
out.release()
# Out:
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_0.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_1.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_2.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_3.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_4.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_5.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_6.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_7.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_8.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_9.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_10.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_11.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_12.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_13.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_14.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_15.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_16.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_17.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_18.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_19.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_20.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_21.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_22.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_23.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_24.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_25.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_26.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_27.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_28.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_29.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_30.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_31.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_32.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_33.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_34.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_35.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_36.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_37.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_38.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_39.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_40.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_41.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_42.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_43.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_44.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_45.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_46.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_47.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_48.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_49.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_50.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_51.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_52.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_53.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_54.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_55.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_56.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_57.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_58.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_59.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_60.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_61.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_62.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_63.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_64.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_65.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_66.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_67.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_68.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_69.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_70.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_71.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_72.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_73.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_74.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_75.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_76.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_77.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_78.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_79.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_80.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_81.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_82.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_83.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_84.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_85.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_86.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_87.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_88.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_89.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_90.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_91.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_92.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_93.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_94.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_95.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_96.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_97.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_98.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_99.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_100.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_101.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_102.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_103.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_104.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_105.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_106.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_107.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_108.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_109.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_110.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_111.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_112.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_113.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_114.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_115.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_116.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_117.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_118.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_119.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_120.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_121.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_122.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_123.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_124.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_125.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_126.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_127.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_128.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_129.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_130.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_131.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_132.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_133.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_134.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_135.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_136.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_137.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_138.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_139.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_140.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_141.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_142.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_143.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_144.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_145.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_146.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_147.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_148.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_149.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_150.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_151.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_152.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_153.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_154.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_155.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_156.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_157.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_158.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_159.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_160.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_161.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_162.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_163.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_164.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_165.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_166.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_167.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_168.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_169.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_170.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_171.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_172.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_173.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_174.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_175.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_176.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_177.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_178.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_179.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_180.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_181.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_182.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_183.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_184.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_185.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_186.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_187.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_188.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_189.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_190.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_191.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_192.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_193.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_194.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_195.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_196.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_197.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_198.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_199.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_200.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_201.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_202.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_203.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_204.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_205.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_206.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_207.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_208.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_209.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_210.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_211.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_212.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_213.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_214.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_215.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_216.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_217.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_218.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_219.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_220.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_221.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_222.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_223.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_224.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_225.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_226.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_227.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_228.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_229.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_230.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_231.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_232.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_233.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_234.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_235.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_236.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_237.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_238.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_239.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_240.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_241.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_242.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_243.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_244.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_245.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_246.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_247.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_248.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_249.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_250.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_251.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_252.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_253.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_254.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_255.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_256.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_257.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_258.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_259.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_260.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_261.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_262.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_263.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_264.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_265.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_266.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_267.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_268.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_269.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_270.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_271.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_272.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_273.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_274.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_275.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_276.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_277.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_278.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_279.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_280.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_281.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_282.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_283.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_284.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_285.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_286.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_287.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_288.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_289.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_290.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_291.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_292.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_293.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_294.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_295.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_296.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_297.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_298.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_299.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_300.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_301.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_302.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_303.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_304.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_305.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_306.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_307.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_308.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_309.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_310.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_311.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_312.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_313.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_314.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_315.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_316.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_317.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_318.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_319.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_320.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_321.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_322.jpg True
# /home/yudzyoga/Documents/Courses/2ndSemester/3DCV/Assignments/github/3dcv_group_10/Project/dataset/milk_stage2/result/run3/record_323.jpg True
